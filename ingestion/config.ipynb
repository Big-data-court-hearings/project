# %%
"""
Central configuration file for the ingestion pipeline.

This module contains:
- API configuration
- paths
- ingestion limits
- request parameters

The objective is to centralize all configurable
parameters in a single location.
"""

from pathlib import Path

# ============================================================
# PROJECT ROOT
# ============================================================

# Root project directory
PROJECT_ROOT = Path.cwd()

# ============================================================
# BRONZE LAYER PATHS
# ============================================================

BRONZE_PATH = PROJECT_ROOT / "bronze"

DOCKETS_PATH = BRONZE_PATH / "dockets"
COURTS_PATH = BRONZE_PATH / "courts"
APPEALS_PATH = BRONZE_PATH / "appeals"

# ============================================================
# API CONFIGURATION
# ============================================================

API_TOKEN = "03aff4672ad061fa70a808bc3e81d802013fa865"
BASE_URL = "https://www.courtlistener.com/api/rest/v4/"

HEADERS = {
    "Authorization": f"Token {API_TOKEN}"
}

# ============================================================
# INGESTION PARAMETERS
# ============================================================

# Maximum number of records to download
MAX_RECORDS = 1000

# Timeout for API requests
REQUEST_TIMEOUT = 30

# Number of retries before failure

MAX_RETRIES = 3
